# %%
#!/usr/bin/env python3

import os
import numpy as np
import pandas as pd
import tensorflow as tf

#os.chdir('CANlabStudy')
fnames = os.listdir()

def generateSubjects(fnames):
    return([fname[:3] for fname in fnames])

subs = list(dict.fromkeys(generateSubjects(fnames)))

column_names = ['subject', 'group', 'p300', 'flanker', 'chronic', 'rest']

data = pd.DataFrame(columns=column_names)
data['subject'] = subs
data.set_index('subject', inplace=True)
for sub in subs:
    if (int(sub) in range(100, 199)):
        data.loc[sub]['group']=1
    elif (int(sub) in range(200, 299)):
        data.loc[sub]['group']=2
    else:
        data.loc[sub]['group']=0

ends=[
    '_P300_Eyes_Closed.eeg',
    '_Flanker_Test.eeg',
    '_EO_Baseline_12.eeg',
    '_EO_Baseline_8.eeg']

def populateTasks(df, fnames):
    for sub in subs:
        if (sub + ends[0]) in fnames:
            df.loc[sub]['p300']=[['eeg','NaN'],['art','NaN'],['evt','NaN']]
        else:
            df.loc[sub]['p300']="none"
        if (sub + ends[1]) in fnames:
            df.loc[sub]['flanker']=[['eeg','NaN'],['art','NaN'],['evt','NaN']]
        else:
            df.loc[sub]['flanker']="none"
        if (sub + ends[2]) in fnames:
            df.loc[sub]['chronic']=[['eeg','NaN'],['art','NaN']]
        else:
            df.loc[sub]['chronic']="none"
        if (sub + ends[3]) in fnames:
            df.loc[sub]['rest']=[['eeg','NaN'],['art','NaN']]
        else:
            df.loc[sub]['rest']="none"
        
populateTasks(data, fnames)
data
# Out:
#         group                                  p300  \
# subject
# 112         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 201         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 109         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 103         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 206         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 110         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 104         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 205         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 202         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 100         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 101         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 107         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 105         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 001         0  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 204         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
#
#                                       flanker                   chronic  \
# subject
# 112      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 201      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 109      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 103      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 206      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 110      [[eeg, NaN], [art, NaN], [evt, NaN]]                      none
# 104      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 205      [[eeg, NaN], [art, NaN], [evt, NaN]]                      none
# 202      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 100      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 101      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 107      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 105      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 001      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 204      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
#
#                              rest
# subject
# 112      [[eeg, NaN], [art, NaN]]
# 201      [[eeg, NaN], [art, NaN]]
# 109      [[eeg, NaN], [art, NaN]]
# 103      [[eeg, NaN], [art, NaN]]
# 206      [[eeg, NaN], [art, NaN]]
# 110      [[eeg, NaN], [art, NaN]]
# 104      [[eeg, NaN], [art, NaN]]
# 205      [[eeg, NaN], [art, NaN]]
# 202      [[eeg, NaN], [art, NaN]]
# 100                          none
# 101      [[eeg, NaN], [art, NaN]]
# 107      [[eeg, NaN], [art, NaN]]
# 105      [[eeg, NaN], [art, NaN]]
# 001                          none
# 204      [[eeg, NaN], [art, NaN]]

# %%
def loadEEGdata(df):
    channel_names = [
        'C1',
        'C2',
        'C3',
        'C4',
        'C5',
        'C6',
        'C7',
        'C8',
        'C9',
        'C10',
        'C11',
        'C12',
        'C13',
        'C14',
        'C15',
        'C16',
        'C17',
        'C18',
        'C19'
    ]
    for sub in df.index.values:
        for task in df.columns:
            if df.loc[sub][task]!="none":
                if task=="p300":
                    df.loc[sub][task][0][1]=pd.read_csv(sub+ends[0][:-4]+'.eeg', delimiter=' ', names=channel_names, index_col=False)
                    df.loc[sub][task][1][1]=pd.read_csv(sub+ends[0][:-4]+'.art', delimiter=' ', names=channel_names, index_col=False)
                    df.loc[sub][task][2][1]=pd.read_csv(sub+ends[0][:-4]+'.evt', delimiter=' ', names=channel_names, index_col=False)
                if task=="flanker":
                    df.loc[sub][task][0][1]=pd.read_csv(sub+ends[1][:-4]+'.eeg', delimiter=' ', names=channel_names, index_col=False)
                    df.loc[sub][task][1][1]=pd.read_csv(sub+ends[1][:-4]+'.art', delimiter=' ', names=channel_names, index_col=False)
                    df.loc[sub][task][2][1]=pd.read_csv(sub+ends[1][:-4]+'.evt', delimiter=' ', names=channel_names, index_col=False)
                if task=="chronic":
                    df.loc[sub][task][0][1]=pd.read_csv(sub+ends[2][:-4]+'.eeg', delimiter=' ', names=channel_names, index_col=False)
                    df.loc[sub][task][1][1]=pd.read_csv(sub+ends[2][:-4]+'.art', delimiter=' ', names=channel_names, index_col=False)
                if task=="rest":
                    df.loc[sub][task][0][1]=pd.read_csv(sub+ends[3][:-4]+'.eeg', delimiter=' ', names=channel_names, index_col=False)
                    df.loc[sub][task][1][1]=pd.read_csv(sub+ends[3][:-4]+'.art', delimiter=' ', names=channel_names, index_col=False)
    return(df)

EEG = loadEEGdata(data)
EEG.loc['110']['p300'][0][1]
# Out:
#         C1   C2  C3  C4   C5  C6  C7  C8  C9  C10  C11  C12  C13  C14  C15  \
# 0      104   96  94  83  105  97  79  98  85   91  106  102   71   78  103
# 1      102   94  92  83  103  97  79  97  85   91  106  103   72   80  104
# 2      101   93  91  80  101  91  79  96  85   91  106  101   75   78  104
# 3      102   95  90  78  101  88  80  96  85   91  106  101   78   76  105
# 4      103   96  89  77  101  88  80  96  85   91  105  101   77   74  105
# 5      102   95  88  76  101  89  79  95  83   90  104  100   74   72  103
# 6      104   96  90  78  102  90  79  95  82   90  104  100   74   73  102
# 7      107   98  93  80  103  93  80  96  82   91  105  101   77   79  103
# 8      105   97  91  79  101  91  79  96  80   91  104  100   78   81  103
# 9      102   93  87  74   98  84  78  93  77   88  100   98   77   78  101
# 10     102   92  87  72   99  81  78  92  76   86   99   97   78   72  101
# 11     103   93  88  76  100  84  79  92  76   87   99   97   77   73  100
# 12     102   95  88  79   98  89  79  92  75   87   99   96   74   79   99
# 13     101   97  87  80   96  92  82  91  74   86   98   95   73   83   97
# 14     101   98  87  78   95  91  84  91  73   86   97   94   74   81   97
# 15     102   98  87  75   96  89  84  90  72   85   97   93   75   78   96
# 16     104   98  87  74   97  87  83  89  71   85   96   93   76   77   95
# 17     105   99  88  75   99  87  83  88  72   85   96   93   77   78   96
# 18     106  100  88  77   99  89  84  89  73   86   97   93   77   78   97
# 19     103   99  87  76   97  89  84  89  73   87   97   93   76   78   97
# 20     100   96  85  73   95  85  84  88  72   86   96   93   77   78   96
# 21      98   93  84  69   93  77  83  88  71   85   95   92   77   75   95
# 22      95   88  81  64   91  70  82  88  70   84   94   91   76   72   94
# 23      92   85  79  60   90  68  80  87  69   83   93   90   76   71   93
# 24      92   85  80  60   93  69  80  86  69   83   93   90   76   70   93
# 25      94   86  81  63   94  70  80  86  70   83   93   90   76   67   93
# 26      98   90  84  67   94  73  81  86  71   83   94   91   77   68   94
# 27     101   96  86  71   95  76  81  86  71   83   95   91   79   72   95
# 28     104   99  88  75   97  77  81  86  71   83   94   91   80   74   95
# 29     105  100  89  76   98  76  80  86  70   83   93   90   80   72   94
# ...    ...  ...  ..  ..  ...  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 58790   -5   -7  -4  -3   -1 -14  24  -2  -5   26   -2    0   -3    3   -4
# 58791   -7   -7  -5  -4   -4 -14  23  -1  -4   26   -2    0   -2    3   -4
# 58792   -5   -3  -3   0   -1  -9  24   0  -2   27    0    0    0    7   -2
# 58793   -2    0  -1   4    2  -4  27   1  -1   29    0    1    1   10   -1
# 58794   -2    1  -1   6    2  -3  27   2  -1   29    2    2    1   10   -1
# 58795   -3    0  -3   6    0  -5  26   2  -2   29    1    2    0   10   -2
# 58796   -6   -3  -4   5   -4  -7  24   1  -4   27    0    0   -3    8   -4
# 58797  -10   -8  -8   2   -7 -10  23   0  -5   26   -1    0   -4    5   -5
# 58798  -14  -12 -12   0   -8 -13  22   0  -5   25   -1    0   -4    3   -5
# 58799  -15  -13 -13  -2   -8 -15  23   1  -4   26    0    0   -3    3   -4
# 58800  -16  -12 -14  -4   -8 -15  24   2  -3   27    0    1   -2    4   -3
# 58801  -17  -11 -16  -4   -9 -14  24   3  -2   27    0    1   -1    7   -4
# 58802  -17  -12 -17  -2  -12 -13  23   4  -1   28    0    3   -2   11   -3
# 58803  -20  -13 -18  -1  -14 -13  22   4  -1   28    0    3   -2   13   -3
# 58804  -23  -16 -21  -2  -17 -15  20   2  -2   27    0    1   -3   11   -4
# 58805  -23  -16 -22  -3  -17 -16  19   2  -3   26   -1    0   -3    9   -5
# 58806  -22  -13 -19  -2  -14 -14  20   3  -2   26   -1    0   -3   10   -5
# 58807  -20  -10 -17   1  -12  -8  21   4   0   28    0    2   -1   14   -4
# 58808  -17   -7 -15   5  -10  -3  22   5   0   28    0    2    0   15   -3
# 58809  -14   -6 -14   6   -9  -3  22   3   0   27    0    1    0   12   -3
# 58810  -11   -6 -14   3   -9  -7  20   1  -1   25   -2    0   -1    9   -5
# 58811  -11   -7 -16   0  -11 -10  18   0  -3   23   -4   -2   -3    7   -6
# 58812  -13   -9 -18  -2  -12 -12  17   1  -4   22   -5   -3   -4    5   -6
# 58813  -14   -9 -19  -2  -11 -11  18   2  -3   22   -5   -2   -2    4   -5
# 58814  -12   -6 -16   0   -8  -7  20   3  -1   23   -3   -1    0    7   -4
# 58815   -8   -3 -12   3   -5  -4  21   4   0   25   -1    1    0   11   -2
# 58816   -7   -3 -10   3   -5  -5  21   4   0   26   -1    1    0   11   -3
# 58817   -8   -5 -12   2   -8  -7  20   4  -1   24   -2    0   -1    8   -4
# 58818   -8   -5 -13   1  -10  -8  20   5   0   24   -2    0    0    7   -3
# 58819   -9   -5 -13   0  -10  -8  21   7   2   26    0    2    2    5   -2
#
#        C16  C17  C18  C19
# 0      106   99   99   96
# 1      106  100   99   97
# 2      106   98   98   96
# 3      106   96   98   97
# 4      105   95   99   97
# 5      104   94   98   95
# 6      103   96   99   95
# 7      105   98  100   97
# 8      104   97   98   95
# 9      101   93   94   90
# 10     100   92   93   89
# 11     100   93   94   91
# 12     100   94   95   91
# 13      99   94   95   90
# 14      98   93   93   89
# 15      97   92   90   88
# 16      97   92   88   86
# 17      97   94   88   86
# 18      98   95   89   88
# 19      98   93   88   88
# 20      97   90   87   87
# 21      96   88   86   85
# 22      95   84   84   84
# 23      95   81   83   83
# 24      95   81   83   82
# 25      94   83   84   83
# 26      94   87   87   84
# 27      95   91   89   85
# 28      94   94   89   84
# 29      93   95   88   84
# ...    ...  ...  ...  ...
# 58790   -6    1    0    1
# 58791   -6    0    0    2
# 58792   -4    2    3    5
# 58793   -3    4    5    7
# 58794   -3    4    4    7
# 58795   -4    2    2    7
# 58796   -5    0    2    6
# 58797   -5   -2    3    6
# 58798   -5   -5    3    6
# 58799   -4   -7    3    7
# 58800   -3   -8    3    7
# 58801   -2   -9    5    8
# 58802   -2  -10    7   10
# 58803   -3  -12    9   11
# 58804   -3  -14    7   10
# 58805   -3  -15    4    8
# 58806   -2  -13    4    9
# 58807   -1  -11    6   11
# 58808   -1   -9    8   12
# 58809   -2   -7    6   11
# 58810   -3   -6    3    9
# 58811   -4   -8    0    6
# 58812   -4  -11   -3    5
# 58813   -4  -13   -5    4
# 58814   -3  -11   -4    6
# 58815   -2   -8    0    9
# 58816   -1   -7    3   10
# 58817   -2   -9    3   10
# 58818   -2  -10    4   11
# 58819   -1  -10    5   13
#
# [58820 rows x 19 columns]
