# %%
#!/usr/bin/env python3
import os
import numpy as np
import pandas as pd

# %%
#The CANlab/WAVi Pain Study is Pre-Formatted to resemble BIDS neuroimaging formatting
#If your study does not abide to the following structure, please reformat your study files before continuing
# .../StudyRepo
# ------------------> /raw
# ------------------------> /*.art
# ------------------------> /*.eeg
# ------------------------> /*.evt

# %%
print("Please enter the full path of the study repository:")
repo = input()

while(not os.path.exists(directory)):
    print("\n")
    print("The directory you supplied could not be found.")
    print("Please enter the full path of the study directory containing EEG, ART, EVT files:")
    directory = input()
    
os.chdir(directory)
# Out:
# Please enter the full path of the study repository:
# /home/clayton/science/CANlab/WAViMedEEG/CANlabStudy

# %%
# Takes user-supplied study directory, adds all files in /raw ending with "eeg", "art", "evt" into fnames array
def generateFilenames(directory):
    filenames = [f for f in os.listdir(directory+"/raw") if f.rpartition('.')[2] in ('eeg','art','evt')]
    return(filenames)

# Takes list of study files, length of subject order numbers
def generateSubjects(filenames, places):
    return([f[:places] for f in filenames])

# %%
fnames = generateFilenames(repo)

subs = list(dict.fromkeys(generateSubjects(fnames, 3)))

cnames = ['subject', 'group', 'p300', 'flanker', 'chronic', 'rest']
ends=[
    '_P300_Eyes_Closed.eeg',
    '_Flanker_Test.eeg',
    '_EO_Baseline_12.eeg',
    '_EO_Baseline_8.eeg']

def getGroupNumber(subject):
    if (int(subject) in range(100, 199)):
        return(1)
    elif (int(subject) in range(200, 299)):
        return(2)
    else:
        return(0)

def initializeDataframe(column_names, subjects):
    df = pd.DataFrame(columns=column_names)
    df['subject'] = subjects
    df.set_index('subject', inplace=True)
    for sub in subs: 
        df.loc[sub]['group']=getGroupNumber(sub)
    return(df)

data = initializeDataframe(cnames, subs)

print(data)
# Out:
#         group p300 flanker chronic rest
# subject
# 110         1  NaN     NaN     NaN  NaN
# 206         2  NaN     NaN     NaN  NaN
# 205         2  NaN     NaN     NaN  NaN
# 112         1  NaN     NaN     NaN  NaN
# 107         1  NaN     NaN     NaN  NaN
# 104         1  NaN     NaN     NaN  NaN
# 100         1  NaN     NaN     NaN  NaN
# 109         1  NaN     NaN     NaN  NaN
# 204         2  NaN     NaN     NaN  NaN
# 105         1  NaN     NaN     NaN  NaN
# 001         0  NaN     NaN     NaN  NaN
# 101         1  NaN     NaN     NaN  NaN
# 201         2  NaN     NaN     NaN  NaN
# 103         1  NaN     NaN     NaN  NaN
# 202         2  NaN     NaN     NaN  NaN

# %%
def populateTasks(df, filenames):
    for sub in subs:
        if (sub + ends[0]) in filenames:
            df.loc[sub]['p300']=[['eeg','NaN'],['art','NaN'],['evt','NaN']]
        else:
            df.loc[sub]['p300']="none"
        if (sub + ends[1]) in filenames:
            df.loc[sub]['flanker']=[['eeg','NaN'],['art','NaN'],['evt','NaN']]
        else:
            df.loc[sub]['flanker']="none"
        if (sub + ends[2]) in filenames:
            df.loc[sub]['chronic']=[['eeg','NaN'],['art','NaN']]
        else:
            df.loc[sub]['chronic']="none"
        if (sub + ends[3]) in filenames:
            df.loc[sub]['rest']=[['eeg','NaN'],['art','NaN']]
        else:
            df.loc[sub]['rest']="none"
    return(df)
        
data = populateTasks(data, fnames)
data
# Out:
#         group                                  p300  \
# subject
# 110         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 206         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 205         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 112         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 107         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 104         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 100         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 109         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 204         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 105         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 001         0  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 101         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 201         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 103         1  [[eeg, NaN], [art, NaN], [evt, NaN]]
# 202         2  [[eeg, NaN], [art, NaN], [evt, NaN]]
#
#                                       flanker                   chronic  \
# subject
# 110      [[eeg, NaN], [art, NaN], [evt, NaN]]                      none
# 206      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 205      [[eeg, NaN], [art, NaN], [evt, NaN]]                      none
# 112      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 107      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 104      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 100      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 109      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 204      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 105      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 001      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 101      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 201      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 103      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
# 202      [[eeg, NaN], [art, NaN], [evt, NaN]]  [[eeg, NaN], [art, NaN]]
#
#                              rest
# subject
# 110      [[eeg, NaN], [art, NaN]]
# 206      [[eeg, NaN], [art, NaN]]
# 205      [[eeg, NaN], [art, NaN]]
# 112      [[eeg, NaN], [art, NaN]]
# 107      [[eeg, NaN], [art, NaN]]
# 104      [[eeg, NaN], [art, NaN]]
# 100                          none
# 109      [[eeg, NaN], [art, NaN]]
# 204      [[eeg, NaN], [art, NaN]]
# 105      [[eeg, NaN], [art, NaN]]
# 001                          none
# 101      [[eeg, NaN], [art, NaN]]
# 201      [[eeg, NaN], [art, NaN]]
# 103      [[eeg, NaN], [art, NaN]]
# 202      [[eeg, NaN], [art, NaN]]

# %%
def loadEEGdataNumpy(df):
    os.chdir('raw')
    for sub in df.index.values:
        for task in df.columns:
            if df.loc[sub][task]!="none":
                if task=="p300":
                    df.loc[sub][task][0][1]=np.genfromtxt(sub+ends[0][:-4]+'.eeg', delimiter=' ')
                    df.loc[sub][task][1][1]=np.genfromtxt(sub+ends[0][:-4]+'.art', delimiter=' ')
                    df.loc[sub][task][2][1]=np.genfromtxt(sub+ends[0][:-4]+'.evt', delimiter=' ')
                if task=="flanker":
                    df.loc[sub][task][0][1]=np.genfromtxt(sub+ends[1][:-4]+'.eeg', delimiter=' ')
                    df.loc[sub][task][1][1]=np.genfromtxt(sub+ends[1][:-4]+'.art', delimiter=' ')
                    df.loc[sub][task][2][1]=np.genfromtxt(sub+ends[1][:-4]+'.evt', delimiter=' ')
                if task=="chronic":
                    df.loc[sub][task][0][1]=np.genfromtxt(sub+ends[2][:-4]+'.eeg', delimiter=' ')
                    df.loc[sub][task][1][1]=np.genfromtxt(sub+ends[2][:-4]+'.art', delimiter=' ')
                if task=="rest":
                    df.loc[sub][task][0][1]=np.genfromtxt(sub+ends[3][:-4]+'.eeg', delimiter=' ')
                    df.loc[sub][task][1][1]=np.genfromtxt(sub+ends[3][:-4]+'.art', delimiter=' ')
    os.chdir('..')
    return(df)

EEG = loadEEGdataNumpy(data)
EEG.loc['110']['p300'][0][1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-16e2525f0524> in <module>
#      21     return(df)
#      22
# ---> 23 EEG = loadEEGdataNumpy(data)
#      24 EEG.loc[110]['p300'][0][1]
#
# <ipython-input-21-16e2525f0524> in loadEEGdataNumpy(df)
#       5             if df.loc[sub][task]!="none":
#       6                 if task=="p300":
# ----> 7                     df.loc[sub][task][0][1]=np.genfromtxt(sub+ends[0][:-4]+'.eeg', delimiter=' ')
#       8                     df.loc[sub][task][1][1]=np.genfromtxt(sub+ends[0][:-4]+'.art', delimiter=' ')
#       9                     df.loc[sub][task][2][1]=np.genfromtxt(sub+ends[0][:-4]+'.evt', delimiter=' ')
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2103         rows = list(
#    2104             zip(*[[conv._loose_call(_r) for _r in map(itemgetter(i), rows)]
# -> 2105                   for (i, conv) in enumerate(converters)]))
#    2106     else:
#    2107         rows = list(
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    2103         rows = list(
#    2104             zip(*[[conv._loose_call(_r) for _r in map(itemgetter(i), rows)]
# -> 2105                   for (i, conv) in enumerate(converters)]))
#    2106     else:
#    2107         rows = list(
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    2102     if loose:
#    2103         rows = list(
# -> 2104             zip(*[[conv._loose_call(_r) for _r in map(itemgetter(i), rows)]
#    2105                   for (i, conv) in enumerate(converters)]))
#    2106     else:
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/_iotools.py in _loose_call(self, value)
#     714     def _loose_call(self, value):
#     715         try:
# --> 716             return self.func(value)
#     717         except ValueError:
#     718             return self.default
#
# KeyboardInterrupt:

# %%
import numpy.ma as ma

def artifactEEG(df):
    for sub in df.index.values:
        for task in df.columns[1:]:
            if(df.loc[sub][task]!="none"):
                mx = ma.masked_array(df.loc[sub][task][0][1], mask=df.loc[sub][task][1][1])
                df.loc[sub][task][0][1] = mx
    return(df)

# def artifactEEG(df):
#     for sub in df.index.values:
#         for task in df.columns[1:]:
#             df.loc[sub][task][0][1][df.loc[sub][task][1][1]==0] = np.nan
#     return(df)
              
EEG = artifactEEG(EEG)

# %%
print(EEG.columns[1:])
# Out:
# Index(['p300', 'flanker', 'chronic', 'rest'], dtype='object')

# %%
def writeCSVs(df):
    os.chdir(directory)
    for task in df.columns[1:]:
        os.mkdir(task)
        os.chdir(task)
        os.mkdir('0')
        os.mkdir('1')
        os.mkdir('2')
        os.chdir('..')
        for sub in df.index.values:
            if (df.loc[sub][task]!="none"):
                if len(df.loc[sub][task])>=2:
                    df.loc[sub][task][0][1].tofile(task+'/'+str(df.loc[sub]['group'])+'/'+sub+'_eeg.csv')
                    df.loc[sub][task][1][1].tofile(task+'/'+str(df.loc[sub]['group'])+'/'+sub+'_art.csv')
                if len(df.loc[sub][task])==3:
                    df.loc[sub][task][2][1].tofile(task+'/'+str(df.loc[sub]['group'])+'/'+sub+'_evt.csv')

print("Would you like to overwrite CSV files? y or n")
overwriteCSV = input()
if(overwriteCSV == "y"):
    writeCSVs(EEG)
# Out:
# Would you like to overwrite CSV files? y or n
# n

# %%
# pickles are nice
# EEG.to_pickle("/home/clayton/science/CANlab/WAViMedEEG/EEG.pkl")
# they're not that nice
