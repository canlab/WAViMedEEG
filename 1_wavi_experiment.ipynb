# %%
import os
import glob
import pprint

import redcap
import pandas as pd

# %%
# Open connection with REDCap server
redcap_token_path = os.path.join(os.path.expanduser("~"), '.server_config/redcap-dataentry-token')
redcap_token_file = open(redcap_token_path, 'r')
redcap_token = redcap_token_file.read().strip()

redcap_project = redcap.Project('https://ncanda.sri.com/redcap/api/', redcap_token, verify_ssl=False)
datadict = redcap_project.export_metadata(format='df', df_kwargs=dict(index_col=None))

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds']
credentials = ServiceAccountCredentials.from_json_keyfile_name('./wavi-eeg-screen-31ef6011b1d3.json', scope)
gc = gspread.authorize(credentials)

# %%
spreadsheet_key = '1cxtMAfEk4HjSPfa1aEvI2mcwSu2gI2a7U5OAwFFKxic'
book = gc.open_by_key(spreadsheet_key)
scheduling = book.worksheet("Scheduling")
participants = book.worksheet("Participants")
scheduling_table = scheduling.get_all_values()
participants_table = participants.get_all_values()

# %%
participants_table
# Out:
# [['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'PARTICIPANT',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'BEHAVIORAL SESSION',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'FMRI SESSION',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['ID ',
#   'REDcap ID',
#   'Last Name',
#   'First Name',
#   'Email',
#   'Phone #',
#   'M/F',
#   'DOB',
#   'Date scheduled',
#   'Day',
#   'Exp time scheduled',
#   'Experimenter',
#   'Subject arrival',
#   'URSI #',
#   'Headset set up notes',
#   'P300 Notes',
#   'Flanker Notes',
#   'Back Pain Notes\n',
#   'Spontaneous Pain Notes',
#   'General Behavioral Notes\n',
#   'Setup notes',
#   'PhysioNotes',
#   'T1 (7 min)',
#   'Back Pain Task (12.5 min)',
#   'Spontaneous Back Pain (8 min)',
#   'Aversiveness (6.5 min)'],
#  ['WAVi_100',
#   'Example: 1234',
#   '',
#   '',
#   '',
#   '(xxx) xxx-xxxx',
#   'M80364378',
#   '',
#   '10/10/2018',
#   'Mon',
#   '9:00 AM - 12:00 PM',
#   'Clayton',
#   '08:03 AM',
#   '',
#   'done',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_100',
#   '3',
#   'Roth',
#   'Matthew',
#   'matthew@marhistorical.com',
#   '(303) 579-4275',
#   'M',
#   '10/4/1967',
#   '5/5/2019',
#   'Sun',
#   '8:30 AM - 11:30 AM',
#   'Clayton',
#   '08:30 AM',
#   'M80338404',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_103',
#   '54',
#   'Gates',
#   'Natalie',
#   'natalie.elinor@gmail.com',
#   '(303) 475-1586',
#   'F',
#   '6/9/1988',
#   '6/8/2019',
#   'Sat',
#   '2:30 PM - 5:30 PM',
#   'Clayton',
#   '02:30 PM',
#   'M80358625',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'bad respiration data',
#   '',
#   '',
#   '',
#   'no aversive sound played, scanner volume accidentally not on'],
#  ['WAVI_104',
#   '29',
#   'Dominguez',
#   'Diana',
#   'Dareyd32@gmail.com',
#   '(575) 639-0281',
#   'F',
#   '8/4/1988',
#   '5/29/2019',
#   'Wed',
#   '10:00 AM - 1:00 PM',
#   'Clayton',
#   '10:00 AM',
#   'M80388383',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_105',
#   '57',
#   'Beck',
#   'Sammie',
#   'Sammie.heckler@gmail.com',
#   '(720) 936-6683',
#   'F',
#   '2/26/1985',
#   '6/28/2019',
#   'Wed',
#   '1:30 - 4:30 PM',
#   'Clayton',
#   '01:25 PM',
#   'M80398637',
#   'Just after headset was set up there was a fire and we had to wait about 20 minutes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_106',
#   '19',
#   'Greeno',
#   'Juli',
#   'Tinkfan64@gmail.com',
#   '(720) 341-7818',
#   'F',
#   '4/1/1964',
#   '7/1/2019',
#   'Mon',
#   '9:30 AM - 12:30 PM',
#   'Clayton',
#   '09:30 AM',
#   'M80355013',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_107',
#   '80',
#   'Sydnor',
#   'William',
#   'il_benedetto@icloud.com',
#   '(303) 810-3740',
#   'M',
#   '10/3/1985',
#   '6/2/2019',
#   'Sun',
#   '7:30 AM - 10:30 AM',
#   'Clayton',
#   '07:30 AM',
#   'M80385648',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_101',
#   '60',
#   'Harvey',
#   'Andrew',
#   'julia.lana.moore@gmail.com',
#   '(978) 460-1467',
#   'M',
#   '11/19/1996',
#   '7/9/2019',
#   'Sun',
#   '7:00 AM - 10:00 AM',
#   'Clayton',
#   '07:00 AM',
#   'M80360606',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_102',
#   '24',
#   'Fritzler',
#   'Tessa',
#   'Tessa.fritzler@gmail.com',
#   '(720) 839-8358',
#   'F',
#   '8/31/1980',
#   '6/9/2019',
#   'Sun',
#   '9:00 AM - 12:00 PM',
#   'Clayton',
#   'x',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_108',
#   '12',
#   'Fahrney',
#   'Cody',
#   'fahrneyc@gmail.com',
#   '(540) 688-7316',
#   'M',
#   '3/10/1988',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_109',
#   '89',
#   'Landreth',
#   'Phil',
#   'Phil@scorporationinc.com',
#   '(303) 883-2451',
#   'M',
#   '10/5/1967',
#   '6/27/2019',
#   'Thur',
#   '2:30 PM - 5:30 PM',
#   'Clayton',
#   '02:30 PM',
#   'M80359778',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_110',
#   '16',
#   'Slaton',
#   'Celena',
#   'celena@slaton.com',
#   '(303) 819-2631',
#   'F',
#   '5/30/1975',
#   '6/27/2019',
#   'Thur',
#   '9:30 AM - 12:30 PM',
#   'Clayton',
#   '09:30 AM',
#   'M80356028',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_201',
#   '67',
#   'Wagner',
#   'Jack',
#   'jack.wagner@colorado.edu',
#   '(720) 539-5291',
#   'M',
#   '5/19/1998',
#   '6/29/2019',
#   'Sat',
#   '2:00 - 5:00 PM',
#   'Clayton',
#   '02:50 PM',
#   'M80326664',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_202',
#   '77',
#   'Chen',
#   'Samuel',
#   'anachronicnomad@gmail.com',
#   '(720) 985-8195',
#   'M',
#   '7/15/1996',
#   '6/28/2019',
#   'Fri',
#   '9:30 AM - 12:30 PM',
#   'Clayton',
#   '09:30 AM',
#   'M80334025',
#   '',
#   '',
#   '',
#   '',
#   'Participant talked during entire session...',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_200',
#   '82',
#   'Noble',
#   'Brittany',
#   'Britt.noble@gmail.com',
#   '(248) 860-9688',
#   'F',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_112',
#   '92',
#   'Logan',
#   'Josuha',
#   'joshlogan1205@gmail.com',
#   '(513) 545-9441',
#   'M',
#   '',
#   '8/13/2019',
#   'Tues',
#   '8:00 - 11:00 AM',
#   'Clayton',
#   '07:50 AM',
#   'M80344913',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_111',
#   '116',
#   'Carsons',
#   'Adam',
#   'Carsonsadam@gmail.com',
#   '(303) 919-0542',
#   'M',
#   '',
#   '8/6/2019',
#   'Tues',
#   '8:30 - 11:30 AM',
#   'Clayton',
#   'x',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_205',
#   '119',
#   'Aldridge',
#   'Kyle',
#   'kaldrid1@msudenver.edu',
#   '(720) 243-0056',
#   'M',
#   '2/3/1988',
#   '8/7/2019',
#   'Wed',
#   '8:30 - 11:30 AM',
#   'Clayton',
#   '8:30 AM',
#   'M80381318',
#   '',
#   '',
#   '',
#   '',
#   'Participant had lower Lumbar Scoliosis',
#   '',
#   '',
#   '',
#   '',
#   'skipped',
#   '',
#   ''],
#  ['WAVI_204',
#   '128',
#   'Bonham',
#   'Eric',
#   'rcbnhm22@gmail.com',
#   '(720) 380-1229',
#   'M',
#   '4/5/1994',
#   '8/13/2019',
#   'Tues',
#   '1:30 - 4:30 PM',
#   'Clayton',
#   '01:30 PM',
#   'M80385998',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'missed ratings at 8:30, 11:30, last. possibly error on bladder inflations, he was asleep as shit.',
#   '',
#   ''],
#  ['WAVI_206',
#   '148',
#   'Belfon',
#   'Robert',
#   'robbelfon@yahoo.com',
#   '(720) 380-1458',
#   'M',
#   '',
#   '8/17/2019',
#   'Sat',
#   '2:30 - 5:30 PM',
#   'Clayton',
#   '02:30 PM',
#   'M80335966',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_207',
#   '135',
#   'Hedberg',
#   'Kim',
#   'boulderkim@gmail.com',
#   '(303) 887-9226',
#   'F',
#   '6/26/1959',
#   '8/30/2019',
#   'Fri',
#   '7:30 - 10:30 AM',
#   'Clayton',
#   '07:30 AM',
#   'M80364378',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'weird 1 fast reponse? possibly on purpose by Yoni haha',
#   '',
#   '',
#   ''],
#  ['WAVI_113',
#   '115',
#   'Hoffman',
#   'Anita',
#   'hoffmanshinkleanita@hotmail.com',
#   '(303) 246-3233',
#   'F',
#   '',
#   '9/21/2019',
#   'Sat',
#   '8:00 - 11:00 AM',
#   'Clayton',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  [' ',
#   '113',
#   'Arnold',
#   'Tia',
#   'Tiar2697@gmail.com',
#   '(720) 254-2918',
#   'F',
#   '5/3/1994',
#   '9/15/2019',
#   'Sun',
#   '12:30 - 3:30 PM',
#   'Clayton',
#   '12:50 PM',
#   'M80391382',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'missed a rating in either chronic or spontaneous, all 0s other than that one ',
#   '',
#   ''],
#  ['WAVI_114',
#   '11',
#   'Kallich',
#   'Sandra',
#   'sandrakallich@gmail.com',
#   '(405) 822-1523',
#   'F',
#   '',
#   '9/26/2019',
#   'Thur',
#   '1:00 - 4:00 PM',
#   'Clayton',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['WAVI_209',
#   '118',
#   'Hunt',
#   'Maddie',
#   'somethinggrunwald@gmail.com',
#   '(720) 299-9313',
#   'F',
#   '5/24/1994',
#   '9/18/2019',
#   'Wed',
#   '12:30 - 3:30 PM',
#   'Clayton',
#   '12:30 PM',
#   'M80397285',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']]
